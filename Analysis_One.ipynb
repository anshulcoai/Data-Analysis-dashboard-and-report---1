# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %% [markdown]
# #LOAD THE DATA

# %%
sales=pd.read_csv('C:\\Users\\pc\\Downloads\\salesmarket.csv')

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# #CLEAN THE DATA

# %%
sales.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
sales.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# <h1>Changing Datatypes</h1>

# %%
sales['Date'] = pd.to_datetime(sales['Date'])

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Sales                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
sales['Date'] = sales['Date'].astype('datetime64[ns]')

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales.head(50)
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 0   750-67-8428   Alex     Yangon        Member  Female
# 1   226-31-3081   Giza  Naypyitaw        Normal  Female
# 2   631-41-3108   Alex     Yangon        Normal  Female
# 3   123-19-1176   Alex     Yangon        Member  Female
# 4   373-73-7910   Alex     Yangon        Member  Female
# 5   699-14-3026   Giza  Naypyitaw        Member  Female
# 6   355-53-5943   Alex     Yangon        Member  Female
# 7   315-22-5665   Giza  Naypyitaw        Member  Female
# 8   665-32-9167   Alex     Yangon        Member  Female
# 9   692-92-5582  Cairo   Mandalay        Member  Female
# 10  351-62-0822  Cairo   Mandalay        Member  Female
# 11  529-56-3974  Cairo   Mandalay        Member  Female
# 12  365-64-0515   Alex     Yangon        Member  Female
# 13  252-56-2699   Alex     Yangon        Member  Female
# 14  829-34-3910   Alex     Yangon        Member  Female
# 15  299-46-1805  Cairo   Mandalay        Member  Female
# ...

# %%
sales.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Sales                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
sales['Time'] = sales['Time'].astype('object')

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales['Total'] = sales['Quantity'] * sales['Unit price']

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 2    631-41-3108   Alex     Yangon        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 998  347-56-2442   Alex     Yangon        Normal    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales['Total'].sum()
# Out:
# np.float64(307587.38)

# %% [markdown]
# <h1>Which Product line generate the most revenue<h1>

# %%
pro=sales.groupby('Product line')['Total'].sum().sort_values(ascending=False)

# %%
pro
# Out:
# Product line
# Food and beverages        53471.28
# Sports and travel         52497.93
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Home and lifestyle        51297.06
# Health and beauty         46851.18
# Name: Total, dtype: float64

# %%
pro.plot(kind='bar', title='Revenue Of Products Categories ')
plt.ylabel('Total')
plt.xlabel('Product line')
plt.show()

# %% [markdown]
# <h1>Total Sales and profit<h1>

# %%
sales['Sales'].sum()
# Out:
# np.float64(322966.749)

# %%
sales['gross income'].sum()
# Out:
# np.float64(15379.368999999999)

# %%
total_sales = sales['Sales'].sum()
total_profit = sales['gross income'].sum()

print(f"Total Sales: {total_sales:.2f}")
print(f"Total Profit: {total_profit:.2f}")
# Out:
# Total Sales: 322966.75
# Total Profit: 15379.37

# %% [markdown]
# <h2>Average Rating per product line<h2>

# %%
avg_rating=sales.groupby('Product line')['Rating'].mean().sort_values(ascending=False)

# %%
avg_rating
# Out:
# Product line
# Food and beverages        7.113218
# Fashion accessories       7.029213
# Health and beauty         7.003289
# Electronic accessories    6.924706
# Sports and travel         6.916265
# Home and lifestyle        6.837500
# Name: Rating, dtype: float64

# %%
colors = cm.viridis(np.linspace(0, 1, len(avg_rating)))
avg_rating.plot(kind='bar', color=colors, title='Average rating per product line')
plt.ylabel('Rating')
plt.xlabel('Product line')
plt.show()

# %% [markdown]
# <h2>Sales By City</h2>

# %%
sales_by_city=sales.groupby('City')['Sales'].sum().sort_values(ascending=False)

# %%
sales_by_city
# Out:
# City
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Mandalay     106197.6720
# Name: Sales, dtype: float64

# %%
colors = cm.tab20(np.linspace(0, 1, len(sales_by_city)))
sales_by_city.plot(kind='pie', colors=colors, title='Sales vary by city', autopct='%1.1f%%', labels=sales_by_city.index)
plt.ylabel('')
plt.xlabel('Most highest sales appear in Naypyitaw')
plt.show()

# %% [markdown]
# <h2>Sales Trend Over line</h2>

# %%
sales['Date'] = pd.to_datetime(sales['Date'])

# %%
sales_trend = sales.groupby('Date')['Sales'].sum()

# %%
sales_trend.head(50)
# Out:
# Date
# 2019-01-01    4745.1810
# 2019-01-02    1945.5030
# 2019-01-03    2078.1285
# 2019-01-04    1623.6885
# 2019-01-05    3536.6835
# 2019-01-06    3614.2050
# 2019-01-07    2834.2440
# 2019-01-08    5293.7325
# 2019-01-09    3021.3435
# 2019-01-10    3560.9490
# 2019-01-11    2114.9625
# 2019-01-12    5184.7635
# 2019-01-13    2451.2040
# 2019-01-14    3966.6165
# 2019-01-15    5944.2600
# 2019-01-16    4289.0820
# 2019-01-17    3142.7550
# 2019-01-18    2780.4735
# 2019-01-19    4914.7245
# 2019-01-20    3655.4490
# 2019-01-21    2392.0995
# 2019-01-22    1704.7695
# 2019-01-23    5994.1875
# 2019-01-24    5402.0505
# 2019-01-25    4700.3670
# 2019-01-26    4457.5125
# 2019-01-27    4635.8970
# 2019-01-28    4999.7115
# 2019-01-29    3516.5655
# 2019-01-30    2558.2620
# 2019-01-31    5232.4965
# 2019-02-01    2444.5365
# 2019-02-02    4140.9480
# 2019-02-03    5467.9275
# 2019-02-04    2439.4965
# 2019-02-05    3031.1295
# 2019-02-06    2905.4235
# 2019-02-07    7228.2105
# ...

# %% [markdown]
# <h2>Which Payment Method is More Used By people </h2>

# %%
sales['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %% [markdown]
# <h4>Branches Count</h4>

# %%
sales['Branch'].value_counts()
# Out:
# Branch
# Alex     340
# Cairo    332
# Giza     328
# Name: count, dtype: int64

# %% [markdown]
# <h1>Which branches or cities are more profitable</h1>

# %%
prof=sales.groupby('Branch')['gross income'].sum().sort_values(ascending=False)
prof
colors = cm.Set2(np.linspace(0, 1, len(prof)))

# Plot the bar chart
prof.plot(kind='bar', color=colors, title='Branches With Their High Profits')
plt.xlabel('Branch')
plt.ylabel('Profit')
plt.show()

# %%
prof=sales.groupby('Branch')['Total'].sum().sort_values(ascending=False)
prof
# Out:
# Branch
# Giza     105303.53
# Alex     101143.21
# Cairo    101140.64
# Name: Total, dtype: float64

# %% [markdown]
# <h2>Ratio of Male and Female</h2>

# %%
sales['Gender'].value_counts()
# Out:
# Gender
# Female    571
# Male      429
# Name: count, dtype: int64

# %% [markdown]
# <h2>Gender Behavior :by Sales and Quantity</h2>

# %%
sales.groupby('Gender')[['Sales','Quantity']].sum()
# Out:
#               Sales  Quantity
# Gender
# Female  194671.8375      3288
# Male    128294.9115      2222

# %% [markdown]
# <h1>Line Chart of Daily Monthly Sales</h1>

# %%
daily_sales = sales.groupby('Date')['Sales'].sum()

colors = cm.coolwarm(np.linspace(0, 1, 1))
daily_sales.plot(kind='line', figsize=(10, 5), color=colors[0], title='Daily Sales Trend', linewidth=1, marker='o', markersize=2)
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sale_category=sales.groupby('Product line')['Sales'].sum().sort_values(ascending=False)
colors = cm.viridis(np.linspace(0, 20, 128, len(sale_category)))
sale_category.plot(kind='bar', color=colors, title='Product with High Sales')
plt.xlabel('Product line')
plt.ylabel('Sales')
plt.show()

# %%
sales['Hour'] = pd.to_datetime(sales['Time'], format='%I:%M:%S %p').dt.hour

# %%
hourly_sales = sales.groupby('Hour')['Sales'].sum().sort_index()

# %%
hourly_sales.sort_values(ascending=False)
# Out:
# Hour
# 19    39699.5130
# 13    34723.2270
# 10    31421.4810
# 15    31179.5085
# 14    30828.3990
# 11    30377.3295
# 12    26065.8825
# 18    26030.3400
# 16    25226.3235
# 17    24445.2180
# 20    22969.5270
# Name: Sales, dtype: float64

# %%
colors = cm.viridis(np.linspace(100, 10, 100))
hourly_sales.plot(kind='line', title='Sales by Hour', color=colors[0], linewidth=2, marker='o', markersize=5)
plt.xlabel('Hour')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# <h1>Gender C</h1>

# %%
sales['Gender'].value_counts()
# Out:
# Gender
# Female    571
# Male      429
# Name: count, dtype: int64

# %% [markdown]
# <h1>Female products preference</h1>

# %%
female_product=sales[sales['Gender']== 'Female']['Product line'].value_counts()

# %%
female_product
# Out:
# Product line
# Fashion accessories       108
# Sports and travel         103
# Food and beverages         98
# Electronic accessories     94
# Home and lifestyle         91
# Health and beauty          77
# Name: count, dtype: int64

# %%
female_product.plot(kind='pie', title='Female Product preference',colors=['#FF19FF', '#0613FF', '#990F19', '#FF1C19'],autopct='%1.1f%%')
plt.show()

# %% [markdown]
# <h1>Male Products preference</h1>

# %%
male_product=sales[sales['Gender']=='Male']['Product line'].value_counts()

# %%
male_product
# Out:
# Product line
# Food and beverages        76
# Electronic accessories    76
# Health and beauty         75
# Fashion accessories       70
# Home and lifestyle        69
# Sports and travel         63
# Name: count, dtype: int64

# %%
colors = cm.Set3(np.linspace(0, 1, len(male_product)))
male_product.plot(kind='pie', colors=colors, title='Male Product Preference', autopct='%1.1f%%', labels=male_product.index)
plt.ylabel('')  # Removes the default ylabel
plt.show()

# %% [markdown]
# <h1>Which part of the day has more sale</h1>

# %%
def get_time_period(hour):
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    else:
        return 'Evening'

sales['Time'] = pd.to_datetime(sales['Time'])
sales['Hour'] = sales['Time'].dt.hour
sales['Period'] = sales['Hour'].apply(get_time_period)

sales['Period'].value_counts()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3724\1419186956.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales['Time'] = pd.to_datetime(sales['Time'])
# Period
# Afternoon    454
# Evening      355
# Morning      191
# Name: count, dtype: int64

# %%
sales['Date'] = pd.to_datetime(sales['Date'])
sales['Day'] = sales['Date'].dt.day_name()
sales['Day'].value_counts()
# Out:
# Day
# Saturday     164
# Tuesday      158
# Wednesday    143
# Friday       139
# Thursday     138
# Sunday       133
# Monday       125
# Name: count, dtype: int64

# %%
weekends = ['Saturday', 'Sunday']
sales['Is_Weekend'] = sales['Day'].isin(weekends)
sales['Is_Weekend'].value_counts()
# Out:
# Is_Weekend
# False    703
# True     297
# Name: count, dtype: int64

# %%
sales.to_csv("cleaned_data.csv", index=False)
